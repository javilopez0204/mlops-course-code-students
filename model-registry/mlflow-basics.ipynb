# %% [markdown]
# # Model registry: MLFlow
#
# Example on how to use the MLFlow model registry to log and register simple variables and files.
#
# ## 1. Install MLFlow

# %%
# !pip install mlflow==2.4.1
# Out:
# Requirement already satisfied: mlflow==2.4.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (8.1.3)
# Requirement already satisfied: cloudpickle<3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (0.17.7)
# Requirement already satisfied: entrypoints<1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (3.1.31)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (6.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (4.23.3)
# Requirement already satisfied: pytz<2024 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2023.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2.31.0)
# Requirement already satisfied: packaging<24 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (23.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (6.6.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (1.11.1)
# Requirement already satisfied: docker<7,>=4.0.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (6.1.3)
# Requirement already satisfied: Flask<3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2.3.2)
# Requirement already satisfied: numpy<2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (1.25.0)
# Requirement already satisfied: scipy<2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (1.10.1)
# Requirement already satisfied: pandas<3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2.0.2)
# Requirement already satisfied: querystring-parser<2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (2.0.16)
# Requirement already satisfied: scikit-learn<2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (1.2.2)
# Requirement already satisfied: pyarrow<13,>=4.0.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (12.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (3.4.3)
# Requirement already satisfied: matplotlib<4 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (3.7.1)
# Requirement already satisfied: gunicorn<21 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (20.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from mlflow==2.4.1) (3.1.2)
# Requirement already satisfied: Mako in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.4.1) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.4.1) (4.6.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.4.1) (2.7.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.4.1) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.4.1) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.4.1) (1.16.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.7 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.4.1) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from docker<7,>=4.0.0->mlflow==2.4.1) (1.6.0)
# Requirement already satisfied: Werkzeug>=2.3.3 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from Flask<3->mlflow==2.4.1) (2.3.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from Flask<3->mlflow==2.4.1) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from Flask<3->mlflow==2.4.1) (1.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from gitpython<4,>=2.1.0->mlflow==2.4.1) (4.0.10)
# Requirement already satisfied: setuptools>=3.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from gunicorn<21->mlflow==2.4.1) (67.6.1)
# Requirement already satisfied: zipp>=0.5 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.4.1) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from Jinja2<4,>=2.11->mlflow==2.4.1) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.4.1) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from pandas<3->mlflow==2.4.1) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.4.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.4.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.4.1) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.4.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.4.1) (3.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/dlri/Documents/TEACHING/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.4.1) (5.0.0)

# %% [markdown]
# ## 2. Load libraries

# %%
import os
from random import random, randint
import mlflow
from mlflow import log_metric, log_param, log_artifact

# %% [markdown]
# ## 3. Start the MLFlow server.
#
# To do this, run the following command in a terminal:
#
# mlflow server --backend-store-uri ./mlruns --default-artifact-root ./mlruns

# %% [markdown]
# ## 4. Set up and create an experiment

# %%
# Configure MLflow
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("mlflow-tutorial")
# Out:
# <Experiment: artifact_location='/Users/dlri/Documents/TEACHING/mlruns/889106188966190362', creation_time=1687078435497, experiment_id='889106188966190362', last_update_time=1687078435497, lifecycle_stage='active', name='mlflow-tutorial', tags={}>

# %% [markdown]
# ## 5. Log parameters, metrics, and artifacts

# %%
# Log a parameter (key-value pair)
log_param("param1", randint(0, 100))
# Out:
# 5

# %%
# Log a metric; metrics can be updated throughout the run
log_metric("foo", random())

# %%
log_metric("foo", random() + 1)

# %%
log_metric("foo", random() + 2)

# %%
# Log an artifact (output file)
if not os.path.exists("outputs"):
    os.makedirs("outputs")
    
with open("outputs/test.txt", "w") as f:
    f.write("Hello world!")
    
log_artifact("outputs")
